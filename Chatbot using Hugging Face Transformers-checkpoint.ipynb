# %% [markdown]
# ## Task : Build a Chatbot using Hugging Face Transformers:
# **Objective** Build a simple conversational chatbot using a pre-trained transformer model from Hugging Face that can interact with users and generate meaningful responses.
#
# **Model Chosen:** For this assignment, I used Qwen/Qwen2.5-0.5B-Instruct, a pre-trained transformer model from Hugging Face designed for instruction-following and conversational text generation.
#
# **Why this model? :** It can generate clear and meaningful responses in a conversational format. It supports multi-turn interactions by using conversation history. It is lightweight and gives faster responses compared to heavier models. It is suitable for building a simple and beginner-friendly chatbot implementation.

# %% [markdown]
# ## Step 1: Install Required Libraries

# %%
pip install -q -U "transformers>=4.37.0" accelerate
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 2: Import Required Libraries

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %% [markdown]
# ## Step 3: Load Pre-trained Transformer Model and Tokenizer

# %%
model_name = "Qwen/Qwen2.5-0.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)

print("Model loaded successfully!")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# C:\Python314\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\munna\.cache\huggingface\hub\models--Qwen--Qwen2.5-0.5B-Instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Model loaded successfully!

# %% [markdown]
# ## Step 4: Define Chatbot Response Function
# This function:
#
#     1.Takes user input
#     2.Adds it to conversation history
#     3.Generates a response using the transformer model
#     4.Returns the chatbot reply along with updated conversation history

# %%
def generate_response(messages):
    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

    generated_ids = model.generate(
        **model_inputs,
        max_new_tokens=80,
        do_sample=True,
        temperature=0.7,
        top_p=0.9
    )

    generated_ids = [
        output_ids[len(input_ids):]
        for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

    return response

# %% [markdown]
# ## Step 5: Build Interactive Chatbot Loop
# The chatbot keeps running until the user types exit or quit.

# %%
print("Chatbot: Hello! I am your AI assistant. Type 'exit' or 'quit' to stop.")

messages = [
    {"role": "system", "content": "You are a helpful and friendly AI assistant."}
]

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Chatbot: Goodbye! Have a great day.")
        break

    messages.append({"role": "user", "content": user_input})

    response = generate_response(messages)

    print("Chatbot:", response)

    messages.append({"role": "assistant", "content": response})
# Out:
# Chatbot: Hello! I am your AI assistant. Type 'exit' or 'quit' to stop.
# You:  Hello
# Chatbot: Hello! How can I assist you today?
# You:  What is Artificial Intelligence?
# Chatbot: Artificial intelligence (AI) is the simulation of human intelligence in machines that are designed to think, learn, and act like humans. This includes tasks such as perception, reasoning, learning, problem-solving, decision-making, creativity, and language processing. AI involves the development of computer systems capable of performing tasks that typically require human intelligence, such as image recognition, natural language understanding, autonomous vehicles, robotics
# You:  Who created Python?
# Chatbot: Python was created by Guido van Rossum, an English programmer and software engineer. He first developed Python in 1989 while at Utrecht University. The name "Python" comes from the Norwegian title of his company, which was originally called "Prolog". Guido Van Rossum was a professor at the University of Amsterdam before he founded the company. Python has since become one of
# You:  Tell me about yourself
# Chatbot: As an AI language model, my primary function is to process and generate text based on the input provided to me. My training data consists of a vast amount of text material from various sources, including books, articles, websites, and other documents. I am constantly being updated and improved through regular retraining with new data.
#
# I have access to a wide range of information and can provide factual answers to common
# You:  That is all, Thanks.
# Chatbot: You're welcome! If you have any more questions or need further assistance, feel free to ask.
# You:  quit
# Chatbot: Goodbye! Have a great day.

# %% [markdown]
# ## Step 6: Explanation of the Workflow:
# Pipeline Flow User
# User Input
#    ↓
# Tokenizer converts text → tokens
#    ↓
# DialoGPT processes conversation context
#    ↓
# Model generates next tokens (response)
#    ↓
# Tokens → Text
#    ↓
# Display Response
#    ↓
# Loop until "exit"
#
# How it Works
#
# -The user enters a message.
# -The tokenizer converts text into token IDs.
# -The model processes the input and generates a response.
# -Conversation history is stored so the chatbot can continue the discussion naturally.
# -The loop runs until the user enters exit or quit.
# Learning Outcomes Achieved
#
# -Understood how transformer-based conversational models work
# -Used a pre-trained NLP model from Hugging Face
# -Performed text generation using a transformer model
# -Built an interactive chatbot
# -Maintained multi-turn conversation flow
# **Conclusion**
# In this assignment, I built a simple console-based chatbot using Hugging Face Transformers and the Qwen/Qwen2.5-0.5B-Instruct model. The chatbot accepts user input, generates meaningful responses, maintains conversation flow, and stops when the user types exit or quit.
#
# This project helped me understand the practical use of transformer models in real-world conversational AI systems.
